# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 指定Excel文件路径
excel_file = 'mirror.xlsx'
# 读取Excel文件
df = pd.read_excel(excel_file)
# 假设Excel文件中有列名为'X'、'Y'和'Z'，分别对应X、Y和Z坐标
x_values = df['x']
y_values = df['y']

# 指定Excel文件路径
excel_file2 = '遮挡损失初始表.xlsx'
# 读取Excel文件
df2 = pd.read_excel(excel_file2)
z_values = df2.mean(axis=1)
z_values = z_values[:1745]
# 现在，x_values、y_values和z_values分别包含了从Excel中读取的X、Y和Z坐标数据
print("x_values1 的长度:", len(x_values))
print("y_values1 的长度:", len(y_values))
print("z_values2 的长度:", len(z_values))
# 创建一个三维坐标系
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制散点图
scatter = ax.scatter(x_values, y_values, z_values, s=5,c=z_values, cmap='viridis')
colorbar = plt.colorbar(scatter, ax=ax, label='Z Values')
ax.scatter(0, 0, 80, color='red', marker='o', s=10)

# z_ticks = [0, 80]  # 自定义Z轴刻度位置
# z_tick_labels = ['0', '80']  # 自定义Z轴刻度标签
# ax.set_zticks(z_ticks)
# ax.set_zticklabels(z_tick_labels)

# 设置坐标轴标签
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('遮挡效率')
# 显示图形
plt.show()
# Out:
# x_values1 的长度: 1745
# y_values1 的长度: 1745
# z_values2 的长度: 1745
# C:\Users\23686\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 36974 (\N{CJK UNIFIED IDEOGRAPH-906E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\23686\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25377 (\N{CJK UNIFIED IDEOGRAPH-6321}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\23686\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25928 (\N{CJK UNIFIED IDEOGRAPH-6548}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\23686\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.scatter(x_values, y_values, s=1)
plt.scatter(0, 0)
# 添加标题和坐标轴标签
plt.xlabel('X')
plt.ylabel('Y')

# 显示图形
plt.show()
